# %% [markdown]
# # CODE APRIL
# Created_by: Promise Ekeh
#
# Date: April 2024
#
# Week 3 ( Day 15- day 21)

# %% [markdown]
# # Day 15
#
# Introduction to Pandas Library, Pandas Series and DataFrame basics, reading and outputting data

# %% [markdown]
# ## 1. What is the difference between Series & DataFrame

# %% [markdown]
# ## 2. Create a list of 12 integers, convert to pandas series

# %%
import numpy as np
import pandas as pd

my_list= np.random.randint(0, 100, 12).tolist()
my_series= pd.Series(my_list)
my_series
# Out:
# 0     34
# 1     60
# 2     12
# 3     25
# 4     88
# 5     45
# 6     22
# 7     73
# 8     40
# 9     22
# 10    74
# 11    18
# dtype: int64

# %%
my_series=pd.Series(np.random.randint(0, 100, 12))
my_series
# Out:
# 0     31
# 1     26
# 2     37
# 3     24
# 4     94
# 5     63
# 6     46
# 7     81
# 8      8
# 9      7
# 10     7
# 11    61
# dtype: int32

# %% [markdown]
# ## 3. Create a dictionary of 10 items with the following keys Name, Age, City, Sex and convert to pandas df. Output df as csv, txt & json files.

# %% [markdown]
# ## 4. Download the attached diabetes dataset and read with pandas

# %% [markdown]
# ## 5. Read this url with pandas (https://raw.githubusercontent.com/plotly/datasets/master/diabetes.csv)

# %% [markdown]
# # Day 16
#
# Pandas functions, Indexing, slicing, selecting and reindexing data in Pandas

# %% [markdown]
# ##  1 What’s the difference between loc & iloc?

# %% [markdown]
# ## 2. Using the diabetes dataset from day 15

# %% [markdown]
# ### 2a Apply 10 pandas function

# %% [markdown]
# ### 2b Get the first 10 rows

# %% [markdown]
# ### 2c Get the last 10 rows

# %% [markdown]
# ### 2d Get the first 5 columns

# %% [markdown]
# ### 2e Select first 5 rows and first 3 columns

# %% [markdown]
# ### 2f Select row at index 2 (3rd row) and all columns

# %% [markdown]
# ### 2g Select rows where Age > 50

# %% [markdown]
# ### 2h Calculate and display correlations between numerical columns

# %% [markdown]
# ##  3 Apply anything you've learnt that we have not covered in the exercises

# %% [markdown]
# # DAY 17
#
# Data cleaning and transformation with Pandas

# %% [markdown]
# ## Read this file https://media.geeksforgeeks.org/wp-content/uploads/nba.csv

# %%
url ='https://media.geeksforgeeks.org/wp-content/uploads/nba.csv'
nba_df = pd.read_csv(url)
nba_df.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %% [markdown]
# ## 1. Display basic information about the dataset

# %%
# 1. Display basic information about the dataset
nba_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      457 non-null    object
#  2   Number    457 non-null    float64
#  3   Position  457 non-null    object
#  4   Age       457 non-null    float64
#  5   Height    457 non-null    object
#  6   Weight    457 non-null    float64
#  7   College   373 non-null    object
#  8   Salary    446 non-null    float64
# dtypes: float64(4), object(5)
# memory usage: 32.3+ KB

# %% [markdown]
#  ## 2. Display summary statistics of numerical columns

# %%
#  2. Display summary statistics of numerical columns
nba_df.describe()
# Out:
#            Number         Age      Weight        Salary
# count  457.000000  457.000000  457.000000  4.460000e+02
# mean    17.678337   26.938731  221.522976  4.842684e+06
# std     15.966090    4.404016   26.368343  5.229238e+06
# min      0.000000   19.000000  161.000000  3.088800e+04
# 25%      5.000000   24.000000  200.000000  1.044792e+06
# 50%     13.000000   26.000000  220.000000  2.839073e+06
# 75%     25.000000   30.000000  240.000000  6.500000e+06
# max     99.000000   40.000000  307.000000  2.500000e+07

# %% [markdown]
#  ## 3. Get the number of unique values in each column

# %%
# 3. Get the number of unique values in each column
for col in nba_df:
    print(f'The number of unique items in col is: {nba_df[col].nunique()}')
# Out:
# ['Avery Bradley' 'Jae Crowder' 'John Holland' 'R.J. Hunter'
#  'Jonas Jerebko' 'Amir Johnson' 'Jordan Mickey' 'Kelly Olynyk'
#  'Terry Rozier' 'Marcus Smart' 'Jared Sullinger' 'Isaiah Thomas'
#  'Evan Turner' 'James Young' 'Tyler Zeller' 'Bojan Bogdanovic'
#  'Markel Brown' 'Wayne Ellington' 'Rondae Hollis-Jefferson' 'Jarrett Jack'
#  'Sergey Karasev' 'Sean Kilpatrick' 'Shane Larkin' 'Brook Lopez'
#  'Chris McCullough' 'Willie Reed' 'Thomas Robinson' 'Henry Sims'
#  'Donald Sloan' 'Thaddeus Young' 'Arron Afflalo' 'Lou Amundson'
#  'Thanasis Antetokounmpo' 'Carmelo Anthony' 'Jose Calderon'
#  'Cleanthony Early' 'Langston Galloway' 'Jerian Grant' 'Robin Lopez'
#  "Kyle O'Quinn" 'Kristaps Porzingis' 'Kevin Seraphin' 'Lance Thomas'
#  'Sasha Vujacic' 'Derrick Williams' 'Tony Wroten' 'Elton Brand'
#  'Isaiah Canaan' 'Robert Covington' 'Joel Embiid' 'Jerami Grant'
#  'Richaun Holmes' 'Carl Landry' 'Kendall Marshall' 'T.J. McConnell'
# ...

# %% [markdown]
#  ## 4. Get the number of missing rows in each column

# %%
# 4. Get the number of missing rows in each column
nba_df.isna().sum()
# Out:
# Name         1
# Team         1
# Number       1
# Position     1
# Age          1
# Height       1
# Weight       1
# College     85
# Salary      12
# dtype: int64

# %% [markdown]
#  ## 5. What’s the data type in all columns?

# %%
#  5. What’s the data type in all columns?
nba_df.dtypes
# Out:
# Name         object
# Team         object
# Number      float64
# Position     object
# Age         float64
# Height       object
# Weight      float64
# College      object
# Salary      float64
# dtype: object

# %% [markdown]
#  ## 6. Change the dtype in age to int

# %%
#  6. Change the dtype in age to int
nba_df['Age']=nba_df['Age'].fillna(0).astype(int).replace(0, pd.NA)
nba_df.dtypes
# Out:
# Name         object
# Team         object
# Number      float64
# Position     object
# Age          object
# Height       object
# Weight      float64
# College      object
# Salary      float64
# dtype: object

# %% [markdown]
#  ## 7. Create new columns firstname and lastname by splitting the name column, make the lastname uppercase and drop ‘name’

# %%
#  7. Create new columns firstname and lastname by splitting the name column, make the lastname uppercase and drop ‘name’
nba_df[['firstname', 'lastname']] = nba_df['Name'].str.split(n=1, expand=True)
nba_df['lastname']=nba_df['lastname'].str.upper()
nba_df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG    25    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF    25    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG    27    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG    22    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF    29   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG    26    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG    24    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C    26    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C    26    7-0   231.0
# 457            NaN             NaN     NaN      NaN  <NA>    NaN     NaN
#
#                College     Salary firstname lastname
# ...

# %% [markdown]
#  ## 8. Remove rows where all columns in the row is empty

# %%
#  8. Remove rows where all columns in the row is empty
nba_df=nba_df.dropna(how='all')
nba_df
# Out:
#               Name            Team  Number Position Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29   6-10   231.0
# ..             ...             ...     ...      ...  ..    ...     ...
# 452     Trey Lyles       Utah Jazz    41.0       PF  20   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26    7-0   231.0
#
#                College     Salary firstname lastname
# 0                Texas  7730337.0     Avery  BRADLEY
# ...

# %% [markdown]
#  ## 9. Remove duplicate rows

# %%
#  9. Remove duplicate rows 
print(f'Number of Duplicated row: {nba_df.duplicated().sum()}')

nba_df=nba_df.drop_duplicates()
# Out:
# Number of Duplicated row: 0

# %% [markdown]
#  ## 10. How many unique College do we have in the data

# %%
#  10. How many unique College do we have in the data 
nba_df['College'].nunique()
# Out:
# 118

# %% [markdown]
#  ## 11. How many teams are in  the data

# %%
#  11. How many teams are in  the data
nba_df['Team'].nunique()
# Out:
# 30

# %% [markdown]
#  ## 12. How would you address missing data (explain the reason)?

# %%
#  12. How would you address missing data (explain the reason)?
nba_df.isna().sum()
# Out:
# Name          0
# Team          0
# Number        0
# Position      0
# Age           0
# Height        0
# Weight        0
# College      84
# Salary       11
# firstname     0
# lastname      0
# dtype: int64

# %% [markdown]
#  ## 13. Set the lastname and position as index

# %%
#  13. Set the lastname and position as index 
# nba_df.set_index(['lastname', 'Position'], inplace=True)
nba_df=nba_df.set_index(['lastname', 'Position'])
nba_df
# Out:
#                             Name            Team  Number Age Height  Weight  \
# lastname Position
# BRADLEY  PG        Avery Bradley  Boston Celtics     0.0  25    6-2   180.0
# CROWDER  SF          Jae Crowder  Boston Celtics    99.0  25    6-6   235.0
# HOLLAND  SG         John Holland  Boston Celtics    30.0  27    6-5   205.0
# HUNTER   SG          R.J. Hunter  Boston Celtics    28.0  22    6-5   185.0
# JEREBKO  PF        Jonas Jerebko  Boston Celtics     8.0  29   6-10   231.0
# ...                          ...             ...     ...  ..    ...     ...
# LYLES    PF           Trey Lyles       Utah Jazz    41.0  20   6-10   234.0
# MACK     PG         Shelvin Mack       Utah Jazz     8.0  26    6-3   203.0
# NETO     PG            Raul Neto       Utah Jazz    25.0  24    6-1   179.0
# PLEISS   C          Tibor Pleiss       Utah Jazz    21.0  26    7-3   256.0
# WITHEY   C           Jeff Withey       Utah Jazz    24.0  26    7-0   231.0
#
# ...

# %% [markdown]
#  ## 14. What’s the maximum, minimum and average age & salary

# %%
#  14. What’s the maximum, minimum and average age & salary
for col in ['Age', 'Salary']:
    print(f"Maximum {col} is {nba_df[col].max()}")
    print(f"Minimum {col} is {nba_df[col].min()}")
    print(f"Average {col} is {nba_df[col].mean()}")
# Out:
# Maximum Age is 40
# Minimum Age is 19
# Average Age is 26.938730853391686
# Maximum Salary is 25000000.0
# Minimum Salary is 30888.0
# Average Salary is 4842684.105381166

# %% [markdown]
#  ## 15. Assuming the height is in feet/inch create a new column Height_cm and calculate the BMI of each player

# %%
new_nba_df = nba_df.copy()

# %%
# split height to feet and inch
new_nba_df[['Height_ft', 'Height_inch']]=new_nba_df['Height'].str.split('-', expand=True)
new_nba_df
# Out:
#                             Name            Team  Number Age Height  Weight  \
# lastname Position
# BRADLEY  PG        Avery Bradley  Boston Celtics     0.0  25    6-2   180.0
# CROWDER  SF          Jae Crowder  Boston Celtics    99.0  25    6-6   235.0
# HOLLAND  SG         John Holland  Boston Celtics    30.0  27    6-5   205.0
# HUNTER   SG          R.J. Hunter  Boston Celtics    28.0  22    6-5   185.0
# JEREBKO  PF        Jonas Jerebko  Boston Celtics     8.0  29   6-10   231.0
# ...                          ...             ...     ...  ..    ...     ...
# LYLES    PF           Trey Lyles       Utah Jazz    41.0  20   6-10   234.0
# MACK     PG         Shelvin Mack       Utah Jazz     8.0  26    6-3   203.0
# NETO     PG            Raul Neto       Utah Jazz    25.0  24    6-1   179.0
# PLEISS   C          Tibor Pleiss       Utah Jazz    21.0  26    7-3   256.0
# WITHEY   C           Jeff Withey       Utah Jazz    24.0  26    7-0   231.0
#
# ...

# %%
# convert height_feet & height_inch to meter
new_nba_df['height_m']= (new_nba_df['Height_ft'].astype(int)*0.3048) + (new_nba_df['Height_inch'].astype(int)*0.0254)
new_nba_df.head(10)
# Out:
#                             Name            Team  Number Age Height  Weight  \
# lastname Position
# BRADLEY  PG        Avery Bradley  Boston Celtics     0.0  25    6-2   180.0
# CROWDER  SF          Jae Crowder  Boston Celtics    99.0  25    6-6   235.0
# HOLLAND  SG         John Holland  Boston Celtics    30.0  27    6-5   205.0
# HUNTER   SG          R.J. Hunter  Boston Celtics    28.0  22    6-5   185.0
# JEREBKO  PF        Jonas Jerebko  Boston Celtics     8.0  29   6-10   231.0
# ...                          ...             ...     ...  ..    ...     ...
# LYLES    PF           Trey Lyles       Utah Jazz    41.0  20   6-10   234.0
# MACK     PG         Shelvin Mack       Utah Jazz     8.0  26    6-3   203.0
# NETO     PG            Raul Neto       Utah Jazz    25.0  24    6-1   179.0
# PLEISS   C          Tibor Pleiss       Utah Jazz    21.0  26    7-3   256.0
# WITHEY   C           Jeff Withey       Utah Jazz    24.0  26    7-0   231.0
#
# ...

# %%
# convert weight in pounds to kg
new_nba_df['Weight_kg']=new_nba_df['Weight']*0.453592
new_nba_df.head(10)
# Out:
#                             Name            Team  Number Age Height  Weight  \
# lastname Position
# BRADLEY  PG        Avery Bradley  Boston Celtics     0.0  25    6-2   180.0
# CROWDER  SF          Jae Crowder  Boston Celtics    99.0  25    6-6   235.0
# HOLLAND  SG         John Holland  Boston Celtics    30.0  27    6-5   205.0
# HUNTER   SG          R.J. Hunter  Boston Celtics    28.0  22    6-5   185.0
# JEREBKO  PF        Jonas Jerebko  Boston Celtics     8.0  29   6-10   231.0
# ...                          ...             ...     ...  ..    ...     ...
# LYLES    PF           Trey Lyles       Utah Jazz    41.0  20   6-10   234.0
# MACK     PG         Shelvin Mack       Utah Jazz     8.0  26    6-3   203.0
# NETO     PG            Raul Neto       Utah Jazz    25.0  24    6-1   179.0
# PLEISS   C          Tibor Pleiss       Utah Jazz    21.0  26    7-3   256.0
# WITHEY   C           Jeff Withey       Utah Jazz    24.0  26    7-0   231.0
#
# ...

# %%
# Calculate the BMI
new_nba_df['bmi']=new_nba_df['Weight_kg']/ (new_nba_df['height_m']**2)
new_nba_df.head(10)
# Out:
#                             Name            Team  Number Age Height  Weight  \
# lastname Position
# BRADLEY  PG        Avery Bradley  Boston Celtics     0.0  25    6-2   180.0
# CROWDER  SF          Jae Crowder  Boston Celtics    99.0  25    6-6   235.0
# HOLLAND  SG         John Holland  Boston Celtics    30.0  27    6-5   205.0
# HUNTER   SG          R.J. Hunter  Boston Celtics    28.0  22    6-5   185.0
# JEREBKO  PF        Jonas Jerebko  Boston Celtics     8.0  29   6-10   231.0
# ...                          ...             ...     ...  ..    ...     ...
# LYLES    PF           Trey Lyles       Utah Jazz    41.0  20   6-10   234.0
# MACK     PG         Shelvin Mack       Utah Jazz     8.0  26    6-3   203.0
# NETO     PG            Raul Neto       Utah Jazz    25.0  24    6-1   179.0
# PLEISS   C          Tibor Pleiss       Utah Jazz    21.0  26    7-3   256.0
# WITHEY   C           Jeff Withey       Utah Jazz    24.0  26    7-0   231.0
#
# ...

# %%
# Everything together
new_nba_df['bmi']=(new_nba_df['Weight']*0.453592 ) /(((new_nba_df['Height_ft'].astype(int)*0.3048) + (new_nba_df['Height_inch'].astype(int)*0.0254)) ** 2)
new_nba_df.head(10)
# Out:
#                             Name            Team  Number Age Height  Weight  \
# lastname Position
# BRADLEY  PG        Avery Bradley  Boston Celtics     0.0  25    6-2   180.0
# CROWDER  SF          Jae Crowder  Boston Celtics    99.0  25    6-6   235.0
# HOLLAND  SG         John Holland  Boston Celtics    30.0  27    6-5   205.0
# HUNTER   SG          R.J. Hunter  Boston Celtics    28.0  22    6-5   185.0
# JEREBKO  PF        Jonas Jerebko  Boston Celtics     8.0  29   6-10   231.0
# ...                          ...             ...     ...  ..    ...     ...
# LYLES    PF           Trey Lyles       Utah Jazz    41.0  20   6-10   234.0
# MACK     PG         Shelvin Mack       Utah Jazz     8.0  26    6-3   203.0
# NETO     PG            Raul Neto       Utah Jazz    25.0  24    6-1   179.0
# PLEISS   C          Tibor Pleiss       Utah Jazz    21.0  26    7-3   256.0
# WITHEY   C           Jeff Withey       Utah Jazz    24.0  26    7-0   231.0
#
# ...

# %%
# convert to centimeters
new_nba_df['bmi']=(new_nba_df['Weight']*0.453592 * 10000) /(((new_nba_df['Height_ft'].astype(int)*30.48) + (new_nba_df['Height_inch'].astype(int)*2.54)) ** 2)
new_nba_df
# Out:
#                             Name            Team  Number Age Height  Weight  \
# lastname Position
# BRADLEY  PG        Avery Bradley  Boston Celtics     0.0  25    6-2   180.0
# CROWDER  SF          Jae Crowder  Boston Celtics    99.0  25    6-6   235.0
# HOLLAND  SG         John Holland  Boston Celtics    30.0  27    6-5   205.0
# HUNTER   SG          R.J. Hunter  Boston Celtics    28.0  22    6-5   185.0
# JEREBKO  PF        Jonas Jerebko  Boston Celtics     8.0  29   6-10   231.0
# ...                          ...             ...     ...  ..    ...     ...
# LYLES    PF           Trey Lyles       Utah Jazz    41.0  20   6-10   234.0
# MACK     PG         Shelvin Mack       Utah Jazz     8.0  26    6-3   203.0
# NETO     PG            Raul Neto       Utah Jazz    25.0  24    6-1   179.0
# PLEISS   C          Tibor Pleiss       Utah Jazz    21.0  26    7-3   256.0
# WITHEY   C           Jeff Withey       Utah Jazz    24.0  26    7-0   231.0
#
# ...

# %% [markdown]
# # Day 18:
#
# Data wrangling with Pandas (Joining, merging, and concatenating)

# %% [markdown]
# ## 1. What's the Difference Between merge, join, and concatenate in Pandas?

# %% [markdown]
# ## 2. Explain the Concept of Inner and Outer Join in DataFrame Merging
#
# Inner Join: Returns only the rows where the merge/intersection of the keys (columns) exist in both DataFrames.
#
#
# Outer Join: Returns all rows from both DataFrames, filling in missing values with NaN where keys do not match.

# %% [markdown]
# ## 3. Given these lists

# %%
# 3 Given these lists
name1 = ['Alice', 'Bob', 'Charlie', 'David', 'Emma']
age1 = [25, 30, 35, 40, 45]
gender1 = ['Female', 'Male', 'Male', 'Male', 'Female']


name2 = ['Frank', 'Grace', 'Hannah', 'Isaac', 'Jack']
age2 = [50, 55, 60, 65, 70]
gender2 = ['Male', 'Female', 'Female', 'Male', 'Male']


city = ['NY', 'LA', 'Chicago', 'Houston', 'Miami']
salary = [50000, 60000, 55000, 70000, 65000]

# %% [markdown]
# ## 3a Create 3 dataframes df1 with list with 1s, df2 with lists with 2s df3 city & salary

# %%
df1 = pd.DataFrame({'name': name1,
                   'age': age1,
                   'gender': gender1})
df1

# %%
df2 = pd.DataFrame({'name': name2,
                   'age': age2,
                   'gender': gender2})
df2
# Out:
#      name  age  gender
# 0   Frank   50    Male
# 1   Grace   55  Female
# 2  Hannah   60  Female
# 3   Isaac   65    Male
# 4    Jack   70    Male

# %%
df3 = pd.DataFrame({'city': city,
                   'salary': salary})
df3
# Out:
#       city  salary
# 0       NY   50000
# 1       LA   60000
# 2  Chicago   55000
# 3  Houston   70000
# 4    Miami   65000

# %% [markdown]
# ### 3b Concatenate df1 and df2 DataFrames along rows

# %%
pd.concat([df1, df2], ignore_index=True)

# %% [markdown]
# ### 3c Concatenate df1 and df3 DataFrames along axis

# %%
pd.concat([df1, df3], axis=1)

# %% [markdown]
# ### 3d Combine df1, df2 & df3

# %%
df1.merge(df2, how='outer').join(df3)

# %%
pd.concat([df1, df2, df3])
# Out:
#       name   age  gender     city   salary
# 0    Alice  25.0  Female      NaN      NaN
# 1      Bob  30.0    Male      NaN      NaN
# 2  Charlie  35.0    Male      NaN      NaN
# 3    David  40.0    Male      NaN      NaN
# 4     Emma  45.0  Female      NaN      NaN
# 0    Frank  50.0    Male      NaN      NaN
# 1    Grace  55.0  Female      NaN      NaN
# 2   Hannah  60.0  Female      NaN      NaN
# 3    Isaac  65.0    Male      NaN      NaN
# 4     Jack  70.0    Male      NaN      NaN
# 0      NaN   NaN     NaN       NY  50000.0
# 1      NaN   NaN     NaN       LA  60000.0
# 2      NaN   NaN     NaN  Chicago  55000.0
# 3      NaN   NaN     NaN  Houston  70000.0
# 4      NaN   NaN     NaN    Miami  65000.0

# %%
df1.merge(df2, how='outer').join(df3, how='left')
# Out:
#       name  age  gender     city   salary
# 0    Alice   25  Female       NY  50000.0
# 1      Bob   30    Male       LA  60000.0
# 2  Charlie   35    Male  Chicago  55000.0
# 3    David   40    Male  Houston  70000.0
# 4     Emma   45  Female    Miami  65000.0
# 5    Frank   50    Male      NaN      NaN
# 6    Grace   55  Female      NaN      NaN
# 7   Hannah   60  Female      NaN      NaN
# 8    Isaac   65    Male      NaN      NaN
# 9     Jack   70    Male      NaN      NaN

# %%
df1.merge(df2, how='outer').join(df3, how='right')
# Out:
#       name  age  gender     city  salary
# 0    Alice   25  Female       NY   50000
# 1      Bob   30    Male       LA   60000
# 2  Charlie   35    Male  Chicago   55000
# 3    David   40    Male  Houston   70000
# 4     Emma   45  Female    Miami   65000

# %% [markdown]
# ### 3e Create a Series with names from df1 and concatenate with df3

# %%
name_series=df1['name']
pd.concat([name_series, df3])

# %%
df3['name']=name_series
df3
# Out:
#       city  salary     name
# 0       NY   50000    Alice
# 1       LA   60000      Bob
# 2  Chicago   55000  Charlie
# 3  Houston   70000    David
# 4    Miami   65000     Emma

# %% [markdown]
# ### 3f Merge df1 and df3 based on 'Name' column

# %%
df1.merge(df3)

# %% [markdown]
# ### 3g Join df2 and df3 based on index with suffixes

# %%
df2.merge(df3, how='outer')

# %% [markdown]
# ### 3h Merge DataFrames using Different Join Types (Merging)

# %% [markdown]
# # Day 19
# Grouping, aggregating, reshaping, pivot table, melt dataframs with Pandas

# %% [markdown]
# ## 1. What is the difference between pivot and pivot_tables?
#
# pivot: This is used to reshape data based on column values. It takes three arguments: index, columns, and values.
#
#
# pivot_table: This is a generalization of pivot that allows for aggregation of numeric data when there are duplicate entries.

# %% [markdown]
# ## 2. What is the difference between wide & long tables?
# Wide Table: Data is represented with multiple variables (columns) as different columns.
#
# Long Table (or Tidy Data): Data is represented with multiple variables (columns) as different rows.

# %% [markdown]
# ## 3. What pandas functions can you use to change from wide to long and vice versa?
#
# For changing from wide to long format: pd.melt()
#
# For changing from long to wide format: pd.pivot() or pd.pivot_table()

# %% [markdown]
# ## 4. You are a manager of a store outlet in your city, with 5 sales representatives,
# create a sale inventory DataFrame for the 1st quarter of 2024.
#
# Columns: Name, sex, product, total_sales_number, total_sales_cost (add other columns as you wish)

# %%
np.random.seed(100)
data = {
    'Name': ['John', 'Alice', 'Bob', 'Charlie', 'Emma'] * 15,
    'Sex': ['M', 'F', 'M', 'M', 'F'] * 15,
    'Product': np.random.choice(['A', 'B', 'C', 'D', 'E'], size=75),
    'Month': np.random.randint(1, 4, size=75),
    'Total_Sales_Number': np.random.randint(10, 100, size=75),
    'Total_Sales_Cost': np.random.randint(50000, 200000, size=75)
}

# Create the sale inventory DataFrame
sale_inventory_df = pd.DataFrame(data)
sale_inventory_df
# Out:
#        Name Sex Product  Month  Total_Sales_Number  Total_Sales_Cost
# 0      John   M       A      2                  61            120083
# 1     Alice   F       A      3                  44            143082
# 2       Bob   M       D      3                  77            160449
# 3   Charlie   M       A      3                  88            147332
# 4      Emma   F       C      3                  64            142836
# ..      ...  ..     ...    ...                 ...               ...
# 70     John   M       B      3                  44            111451
# 71    Alice   F       A      1                  13            123328
# 72      Bob   M       E      3                  21             71808
# 73  Charlie   M       D      1                  59            199382
# 74     Emma   F       E      2                  39             82730
#
# [75 rows x 6 columns]

# %%
# Convert 'Month' column to datetime format
sale_inventory_df['date'] = pd.to_datetime(sale_inventory_df['Month'].astype(str) + '/1/2024')
sale_inventory_df=sale_inventory_df.sort_values(by='date')
sale_inventory_df
# Out:
#        Name Sex Product  Month  Total_Sales_Number  Total_Sales_Cost  \
# 53  Charlie   M       B      1                  65            172001
# 34     Emma   F       A      1                  35            146896
# 40     John   M       D      1                  65             56359
# 46    Alice   F       A      1                  27            138196
# 26    Alice   F       E      1                  77            144056
# ..      ...  ..     ...    ...                 ...               ...
# 32      Bob   M       B      3                  23            148628
# 33  Charlie   M       D      3                  91             89094
# 39     Emma   F       C      3                  32             54929
# 58  Charlie   M       D      3                  90            163399
# 37      Bob   M       B      3                  21            134746
#
#          date
# 53 2024-01-01
# 34 2024-01-01
# 40 2024-01-01
# 46 2024-01-01
# 26 2024-01-01
# ..        ...
# 32 2024-03-01
# ...

# %%
sale_inventory_df['Month']=sale_inventory_df['Month'].replace({1:'January', 2:'Feburary', 3:'March'})
sale_inventory_df
# Out:
#        Name Sex Product    Month  Total_Sales_Number  Total_Sales_Cost  \
# 53  Charlie   M       B  January                  65            172001
# 34     Emma   F       A  January                  35            146896
# 40     John   M       D  January                  65             56359
# 46    Alice   F       A  January                  27            138196
# 26    Alice   F       E  January                  77            144056
# ..      ...  ..     ...      ...                 ...               ...
# 32      Bob   M       B    March                  23            148628
# 33  Charlie   M       D    March                  91             89094
# 39     Emma   F       C    March                  32             54929
# 58  Charlie   M       D    March                  90            163399
# 37      Bob   M       B    March                  21            134746
#
#          date
# 53 2024-01-01
# 34 2024-01-01
# 40 2024-01-01
# 46 2024-01-01
# 26 2024-01-01
# ..        ...
# ...

# %% [markdown]
# ### 4a Get the sum of the total sales

# %%
sale_inventory_df['Total_Sales_Cost'].sum()
# Out:
# 9426743

# %% [markdown]
# ### 4b Calculate the cost of each product and assign to a new column

# %%
sale_inventory_df['Cost_Per_Product'] = sale_inventory_df['Total_Sales_Cost'] / sale_inventory_df['Total_Sales_Number']
sale_inventory_df['Cost_Per_Product']=sale_inventory_df['Cost_Per_Product'].round(2)
sale_inventory_df
# Out:
#        Name Sex Product    Month  Total_Sales_Number  Total_Sales_Cost  \
# 53  Charlie   M       B  January                  65            172001
# 34     Emma   F       A  January                  35            146896
# 40     John   M       D  January                  65             56359
# 46    Alice   F       A  January                  27            138196
# 26    Alice   F       E  January                  77            144056
# ..      ...  ..     ...      ...                 ...               ...
# 32      Bob   M       B    March                  23            148628
# 33  Charlie   M       D    March                  91             89094
# 39     Emma   F       C    March                  32             54929
# 58  Charlie   M       D    March                  90            163399
# 37      Bob   M       B    March                  21            134746
#
#          date  Cost_Per_Product
# 53 2024-01-01           2646.17
# 34 2024-01-01           4197.03
# ...

# %% [markdown]
# ### 4c Get the average sale for each sale rep

# %%
sale_inventory_df.groupby('Name')['Total_Sales_Cost'].mean()
# Out:
# Name
# Alice      129335.533333
# Bob        123949.600000
# Charlie    138995.066667
# Emma       125846.733333
# John       110322.600000
# Name: Total_Sales_Cost, dtype: float64

# %%
sale_inventory_df.groupby('Name')['Total_Sales_Cost'].mean().plot(kind='bar')
# Out:
# <Axes: xlabel='Name'>

# %%
# Total Sales
sale_inventory_df.groupby('Name')['Total_Sales_Cost'].sum().plot(kind='bar')
# Out:
# <Axes: xlabel='Name'>

# %%
# Average sale of each product
sale_inventory_df.groupby('Product')['Total_Sales_Cost'].mean().plot(kind='bar')
# Out:
# <Axes: xlabel='Product'>

# %% [markdown]
# ### 3d Get the average sale for each sale rep for each month

# %%
sale_inventory_df.groupby(['Name', 'Month'])['Total_Sales_Cost'].mean()
# Out:
# Name     Month
# Alice    Feburary    149244.000000
#          January     146852.600000
#          March       101465.666667
# Bob      Feburary    145945.333333
#          January      98751.600000
#          March       132521.428571
# Charlie  Feburary    136006.142857
#          January     159453.333333
#          March       130904.600000
# Emma     Feburary     82713.333333
#          January     115803.500000
#          March       157456.666667
# John     Feburary    123140.666667
#          January      86122.500000
#          March       114301.000000
# Name: Total_Sales_Cost, dtype: float64

# %%
sale_inventory_df.groupby(['Month', 'Name'])['Total_Sales_Cost'].mean().unstack().plot(kind='bar')#, stacked=False)
# Out:
# <Axes: xlabel='Month'>

# %% [markdown]
# ### 4e Get the average sale for each sale rep for each product

# %%
sale_inventory_df.groupby(['Name', 'Product'])['Total_Sales_Cost'].mean()

# %%
sale_inventory_df.groupby(['Name', 'Product'])['Total_Sales_Cost'].mean().unstack().plot(kind='bar')
# Out:
# <Axes: xlabel='Name'>

# %% [markdown]
# ### 4f calculate total_sales for each person in the quarter (hint group by name)

# %%
sale_inventory_df.groupby(['Name'])['Total_Sales_Cost'].sum().plot(kind='bar')

# %% [markdown]
# ### 4g Reshape the DataFrame using pivot table

# %%
# pivot_table = 
pd.pivot_table(sale_inventory_df, values='Total_Sales_Cost', index='Name', columns='Product', aggfunc=np.mean)
# Out:
# C:\Users\promi\AppData\Local\Temp\ipykernel_45116\1264021043.py:2: FutureWarning: The provided callable <function mean at 0x00000201F4F3D620> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   pd.pivot_table(sale_inventory_df, values='Total_Sales_Cost', index='Name', columns='Product', aggfunc=np.mean)
# Product              A              B          C              D              E
# Name
# Alice    135129.714286  123415.000000  126642.50   95270.000000  137662.500000
# Bob      110712.000000  157984.333333  140999.00  123808.000000   95635.500000
# Charlie  158875.500000  172001.000000  116289.00  133525.666667  148384.333333
# Emma     146896.000000  105751.000000  121247.75  135605.200000  122095.333333
# John     131006.000000   94417.000000  130769.50  113434.250000   66380.500000

# %%
pd.pivot_table(sale_inventory_df, values='Total_Sales_Cost', index='Name', columns='Product', aggfunc=np.sum)
# Out:
# C:\Users\promi\AppData\Local\Temp\ipykernel_9280\3354987107.py:1: FutureWarning: The provided callable <function sum at 0x000001C7E4950680> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   pd.pivot_table(sale_inventory_df, values='Total_Sales_Cost', index='Name', columns='Product', aggfunc=np.sum)
# Product         A         B         C         D         E
# Name
# Alice    152561.0  394362.0  338943.0  165098.0  640822.0
# Bob      215333.0  404077.0  172109.0  602780.0  284269.0
# Charlie  301946.0  268907.0  652056.0  261562.0  449587.0
# Emma          NaN  507355.0  354378.0  590434.0  273817.0
# John     293210.0  769765.0  648464.0       NaN   70568.0

# %% [markdown]
# ### 4h Reshape the DataFrame using melt

# %%
pd.melt(sale_inventory_df, id_vars=['Name', 'Sex', 'Product', 'Month'], value_vars=['Total_Sales_Number', 'Total_Sales_Cost'])

# %% [markdown]
# ### 4i Perform aggregation using pivot/pivot table and calculate mean sales by products

# %%
sale_inventory_df.pivot_table(values='Total_Sales_Cost', index='Product', aggfunc=np.mean)

# %% [markdown]
# ### 4j Get the product with the highest sale for the quarter

# %%
sale_inventory_df.groupby('Product')['Total_Sales_Cost'].sum().idxmax()

# %% [markdown]
# ### 4h Based on the analysis done what actions will you take going forward
#
# * Increase inventory for high-selling products

# %% [markdown]
# # Day 20
#
# Time Series Data Analysis with Pandas

# %% [markdown]
# ## Load the DailyDelhiClimateTrain dataset to Pandas DataFrame
# https://www.kaggle.com/datasets/sumanthvrao/daily-climate-time-series-data

# %%
df=pd.read_csv('../Data/DailyDelhiClimateTrain.csv')
df

# %% [markdown]
# ## 2. Convert Index to Datetime:
#
# If the DataFrame doesn't have a datetime index, convert an existing column to datetime format and set it as the index.

# %%
df['date'] = pd.to_datetime(df['date'])
df.set_index('date', inplace=True)
df

# %% [markdown]
# ## 2. Resample the data to monthly frequency and calculate mean values

# %%
monthly_data = df.resample('M').mean()
monthly_data

# %% [markdown]
# ## 3. Calculate rolling mean, sum, or other statistics over a specified window of time.
#
# rolling mean and sum over a 7-day window
#
# what is rolling mean?

# %%
rolling_mean = df['meantemp'].rolling(window=7).mean()
rolling_mean

# %%
rolling_sum = df['meantemp'].rolling(window=7).sum()
rolling_sum
# Out:
# date
# 2013-01-01           NaN
# 2013-01-02           NaN
# 2013-01-03           NaN
# 2013-01-04           NaN
# 2013-01-05           NaN
#                  ...
# 2016-12-28    115.364145
# 2016-12-29    113.316526
# 2016-12-30    111.861764
# 2016-12-31    109.596213
# 2017-01-01    105.596213
# Name: meantemp, Length: 1462, dtype: float64

# %%
# Add rolling mean and rolling sum to the original DataFrame
df['rolling_mean'] = rolling_mean
df['rolling_sum'] = rolling_sum

# %%
# # 3. **Plot Time Series Data:**
# #    - Use Matplotlib or Pandas built-in plotting to visualize the time series data.

# import matplotlib.pyplot as plt
# df['meantemp'].plot(figsize=(10, 6), title='Time Series Plot')
# # df['humidity'].plot(figsize=(10, 6), title='Time Series Plot')
# df['wind_speed'].plot(figsize=(10, 6), title='Time Series Plot')
# plt.xlabel('Date')
# plt.ylabel('Value')
# plt.legend()
# plt.show()

# %% [markdown]
# ## 4. Perform time series analysis such as calculating returns, moving averages, or detecting seasonality.

# %%
df['meantemp_change'] = df['meantemp'].pct_change()
df
# Out:
#              meantemp    humidity  wind_speed  meanpressure  meantemp_change
# date
# 2013-01-01  10.000000   84.500000    0.000000   1015.666667              NaN
# 2013-01-02   7.400000   92.000000    2.980000   1017.800000        -0.260000
# 2013-01-03   7.166667   87.000000    4.633333   1018.666667        -0.031532
# 2013-01-04   8.666667   71.333333    1.233333   1017.166667         0.209302
# 2013-01-05   6.000000   86.833333    3.700000   1016.500000        -0.307692
# ...               ...         ...         ...           ...              ...
# 2016-12-28  17.217391   68.043478    3.547826   1015.565217         0.021804
# 2016-12-29  15.238095   87.857143    6.000000   1016.904762        -0.114959
# 2016-12-30  14.095238   89.666667    6.266667   1017.904762        -0.075000
# 2016-12-31  15.052632   87.000000    7.325000   1016.100000         0.067923
# 2017-01-01  10.000000  100.000000    0.000000   1016.000000        -0.335664
#
# [1462 rows x 5 columns]

# %%
df['meantemp_change'].plot(figsize=(10, 6), title='Time Series Plot')
# Out:
# <Axes: title={'center': 'Time Series Plot'}, xlabel='date'>

# %% [markdown]
# ## 5. Use interpolation or forward/backward filling to handle missing values in time series data.

# %%
df.fillna(method='ffill', inplace=True)
# Out:
# C:\Users\promi\AppData\Local\Temp\ipykernel_9280\4016993326.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill', inplace=True)

# %% [markdown]
# ## 6. Generate a date range and fill missing dates in the DataFrame if necessary.

# %%
df
# Out:
#              meantemp    humidity  wind_speed  meanpressure   Returns
# date
# 2013-01-01  10.000000   84.500000    0.000000   1015.666667       NaN
# 2013-01-02   7.400000   92.000000    2.980000   1017.800000 -0.260000
# 2013-01-03   7.166667   87.000000    4.633333   1018.666667 -0.031532
# 2013-01-04   8.666667   71.333333    1.233333   1017.166667  0.209302
# 2013-01-05   6.000000   86.833333    3.700000   1016.500000 -0.307692
# ...               ...         ...         ...           ...       ...
# 2016-12-28  17.217391   68.043478    3.547826   1015.565217  0.021804
# 2016-12-29  15.238095   87.857143    6.000000   1016.904762 -0.114959
# 2016-12-30  14.095238   89.666667    6.266667   1017.904762 -0.075000
# 2016-12-31  15.052632   87.000000    7.325000   1016.100000  0.067923
# 2017-01-01  10.000000  100.000000    0.000000   1016.000000 -0.335664
#
# [1462 rows x 5 columns]

# %%
idx = pd.date_range(start='2024-01-01', end='2024-12-31', freq='D')
new_df = df.reindex(idx)
new_df
# Out:
#             meantemp  humidity  wind_speed  meanpressure  Returns
# 2024-01-01       NaN       NaN         NaN           NaN      NaN
# 2024-01-02       NaN       NaN         NaN           NaN      NaN
# 2024-01-03       NaN       NaN         NaN           NaN      NaN
# 2024-01-04       NaN       NaN         NaN           NaN      NaN
# 2024-01-05       NaN       NaN         NaN           NaN      NaN
# ...              ...       ...         ...           ...      ...
# 2024-12-27       NaN       NaN         NaN           NaN      NaN
# 2024-12-28       NaN       NaN         NaN           NaN      NaN
# 2024-12-29       NaN       NaN         NaN           NaN      NaN
# 2024-12-30       NaN       NaN         NaN           NaN      NaN
# 2024-12-31       NaN       NaN         NaN           NaN      NaN
#
# [366 rows x 5 columns]
